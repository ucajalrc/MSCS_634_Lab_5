# %%
# ==========================================================
# STEP 1: DATA PREPARATION AND EXPLORATION
# ==========================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering, DBSCAN

from sklearn.metrics import silhouette_score, homogeneity_score, completeness_score

plt.style.use("default")

# -----------------------------
# 1.1 Load the Wine dataset
# -----------------------------
wine = load_wine()
X = wine.data
y = wine.target
feature_names = wine.feature_names

df = pd.DataFrame(X, columns=feature_names)
df["target"] = y

# Show first few rows
display(df.head())

# -----------------------------
# 1.2 Explore dataset structure
# -----------------------------
print("\nDataset Info:")
print(df.info())

print("\nDataset Statistics:")
display(df.describe())

# -----------------------------
# 1.3 Standardize features
# -----------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("\nShape of standardized data:", X_scaled.shape)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# ==========================================================
# STEP 2: HIERARCHICAL CLUSTERING
# ==========================================================

# -----------------------------
# 2.1 Linkage matrix for dendrogram
# -----------------------------
linked = linkage(X_scaled, method="ward")

plt.figure(figsize=(12, 6))
dendrogram(linked, truncate_mode='level', p=5)
plt.title("Dendrogram (Hierarchical Clustering)")
plt.xlabel("Samples")
plt.ylabel("Distance")
plt.show()

# -----------------------------
# 2.2 Try different numbers of clusters
# -----------------------------

for k in [2, 3, 4, 5]:
    model_hc = AgglomerativeClustering(n_clusters=k)
    labels_hc = model_hc.fit_predict(X_scaled)

    plt.figure(figsize=(6, 4))
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels_hc, cmap="viridis")
    plt.title(f"Hierarchical Clustering with k={k}")
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.show()

# %%
# ==========================================================
# STEP 3: DBSCAN CLUSTERING
# ==========================================================

eps_values = [0.3, 0.5, 0.7]
min_samples_values = [3, 5, 10]

results = []

for eps in eps_values:
    for ms in min_samples_values:
        db = DBSCAN(eps=eps, min_samples=ms)
        labels_db = db.fit_predict(X_scaled)

        plt.figure(figsize=(6,4))
        plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels_db, cmap="tab10")
        plt.title(f"DBSCAN (eps={eps}, min_samples={ms})")
        plt.xlabel(feature_names[0])
        plt.ylabel(feature_names[1])
        plt.show()

        # -----------------------------
        # Evaluate only if >1 cluster
        # -----------------------------
        if len(set(labels_db)) > 1 and -1 not in set(labels_db):
            sil = silhouette_score(X_scaled, labels_db)
        else:
            sil = None

        homo = homogeneity_score(y, labels_db) if len(set(labels_db)) > 1 else None
        comp = completeness_score(y, labels_db) if len(set(labels_db)) > 1 else None

        results.append({
            "eps": eps,
            "min_samples": ms,
            "clusters_found": len(set(labels_db)),
            "silhouette": sil,
            "homogeneity": homo,
            "completeness": comp
        })

# Show evaluation metrics
results_df = pd.DataFrame(results)
display(results_df)
# Out:
#    eps  min_samples  clusters_found silhouette homogeneity completeness
# 0  0.3            3               1       None        None         None
# 1  0.3            5               1       None        None         None
# 2  0.3           10               1       None        None         None
# 3  0.5            3               1       None        None         None
# 4  0.5            5               1       None        None         None
# 5  0.5           10               1       None        None         None
# 6  0.7            3               1       None        None         None
# 7  0.7            5               1       None        None         None
# 8  0.7           10               1       None        None         None

# %%
# ==========================================================
# STEP 4: ANALYSIS AND INSIGHTS
# ==========================================================

print("=== SUMMARY OF DBSCAN RESULTS ===")
display(results_df)
# Out:
# === SUMMARY OF DBSCAN RESULTS ===
#    eps  min_samples  clusters_found silhouette homogeneity completeness
# 0  0.3            3               1       None        None         None
# 1  0.3            5               1       None        None         None
# 2  0.3           10               1       None        None         None
# 3  0.5            3               1       None        None         None
# 4  0.5            5               1       None        None         None
# 5  0.5           10               1       None        None         None
# 6  0.7            3               1       None        None         None
# 7  0.7            5               1       None        None         None
# 8  0.7           10               1       None        None         None
